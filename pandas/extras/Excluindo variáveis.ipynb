# %%
import pandas as pd

# %%
dados = pd.read_csv('../aluguel_residencial.csv', sep=';')
dados
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 21821  Apartamento                 Méier        2      0       0    70
# 21822    Quitinete                Centro        0      0       0    27
# 21823  Apartamento           Jacarepaguá        3      1       2    78
# 21824  Apartamento  São Francisco Xavier        2      1       0    48
# 21825  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU  Valor_por_metro Tipo_agregado
# ...

# %%
dados_aux = pd.DataFrame(dados[['Tipo', 'Bairro', 'Vagas', 'Valor', 'IPTU', 'Area']])
dados_aux
# Out:
#               Tipo                Bairro  Vagas   Valor  IPTU  Area
# 0        Quitinete            Copacabana      0  1700.0  60.0    40
# 1             Casa       Jardim Botânico      0  7000.0   0.0   100
# 2      Apartamento                Centro      0   800.0  20.0    15
# 3      Apartamento          Higienópolis      0   800.0   0.0    48
# 4      Apartamento              Cachambi      0  1300.0  17.0    50
# ...            ...                   ...    ...     ...   ...   ...
# 21821  Apartamento                 Méier      0   900.0  48.0    70
# 21822    Quitinete                Centro      0   800.0  25.0    27
# 21823  Apartamento           Jacarepaguá      1  1800.0  40.0    78
# 21824  Apartamento  São Francisco Xavier      1  1400.0  37.0    48
# 21825  Apartamento                Leblon      0  3000.0   0.0    70
#
# [21826 rows x 6 columns]

# %%
# vamos excluir a coluna 'Bairro'

del dados_aux['Bairro']
dados_aux
# Out:
#               Tipo  Vagas   Valor  IPTU  Area
# 0        Quitinete      0  1700.0  60.0    40
# 1             Casa      0  7000.0   0.0   100
# 2      Apartamento      0   800.0  20.0    15
# 3      Apartamento      0   800.0   0.0    48
# 4      Apartamento      0  1300.0  17.0    50
# ...            ...    ...     ...   ...   ...
# 21821  Apartamento      0   900.0  48.0    70
# 21822    Quitinete      0   800.0  25.0    27
# 21823  Apartamento      1  1800.0  40.0    78
# 21824  Apartamento      1  1400.0  37.0    48
# 21825  Apartamento      0  3000.0   0.0    70
#
# [21826 rows x 5 columns]

# %%
# Excluir coluna IPTU
dados_aux.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'IPTU'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
